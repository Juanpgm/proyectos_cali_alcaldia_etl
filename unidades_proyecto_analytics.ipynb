# %%
import sys

sys.path.append('extraction_app')

# %%
gdf
# Out:
#           referencia_proceso  \
# 0    4145.010.32.1.2166-2024
# 1    4145.010.32.1.2172-2024
# 2    4145.010.32.1.1287-2025
# 3    4145.010.32.1.1288-2026
# 4    4145.010.32.1.1289-2027
# ..                       ...
# 874    4143.010.32.0829-2024
# 875    4143.010.32.0829-2024
# 881                     None
# 884    4143.010.32.1762-2025
# 888    4143.010.32.0829-2024
#
#                                    referencia_contrato  bpin  \
# 0                              4145.010.27.1.0037-2024   NaN
# 1                              4145.010.27.1.0039-2024   NaN
# 2                              4145.010.27.1.0034-2025   NaN
# 3                              4145.010.27.1.0035-2026   NaN
# 4                              4145.010.27.1.0036-2027   NaN
# ..                                                 ...   ...
# 874                            4143.010.26.1.1320-2024   NaN
# 875                            4143.010.26.1.1320-2024   NaN
# ...
